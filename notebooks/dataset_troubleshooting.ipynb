'nadir', 'nadir_qtr', 'new', 'pre_peak', 'post_peak', 'pre_peak_qtr', 'post_peak_qtr', 'recovery', 'recovery_list'],
'full':[2000.25, 2000.5, 2000.75, 2001.0, 2001.25, 2001.5, 2001.75, 2002.0, 2002.25, 2002.5, 2002.75, 2003.0, 2003.25, 2003.5, 2003.75, 2004.0, 2004.25, 2004.5, 2004.75, 2005.0, 2005.25, 2005.5, 2005.75, 2006.0, 2006.25, 2006.5, 2006.75, 2007.0, 2007.25, 2007.5, 2007.75, 2008.0, 2008.25, 2008.5, 2008.75, 2009.0, 2009.25, 2009.5, 2009.75, 2010.0, 2010.25, 2010.5, 2010.75, 2011.0, 2011.25, 2011.5, 2011.75, 2012.0, 2012.25, 2012.5, 2012.75, 2013.0, 2013.25, 2013.5, 2013.75, 2014.0, 2014.25, 2014.5, 2014.75, 2015.0, 2015.25, 2015.5, 2015.75, 2016.0, 2016.25, 2016.5, 2016.75, 2017.0, 2017.25, 2017.5, 2017.75, 2018.0, 2018.25, 2018.5, 2018.75, 2019.0, 2019.25, 2019.5, 2019.75, 2020.0, 'nadir', 'nadir_qtr', 'new', 'pre_peak', 'post_peak', 'pre_peak_qtr', 'post_peak_qtr', 'recovery', 'recovery_list']}

#schema for importing dataframe
schema_dict = { 'area_fips':str,  'own_code':str,  'industry_code':str,  'agglvl_code':str,  'size_code':str,  'year':int,  'qtr':int,  'disclosure_code':str, 'area_title':str,  'own_title':str,  'industry_title':str,  'agglvl_title':str,  'size_title':str,  'qtrly_estabs':int,  'month1_emplvl':int,  'month2_emplvl':int,  'month3_emplvl':int,  'total_qtrly_wages':int,  'taxable_qtrly_wages':int,  'qtrly_contributions':int,  'avg_wkly_wage':int,  'lq_disclosure_code':str,  'lq_qtrly_estabs':float,  'lq_month1_emplvl':float,  'lq_month1_emplv2':float,  'lq_month1_emplv3':float,  'lq_total_qtrly_wages':float,  'lq_taxable_qtrly_wages':float,  'lq_qrtly_contributions':float,  'oty_disclosure_code':str,  'oty_qtrly_estabs':int,  'oty_qtrly_estabs_pct_chg':float,  'oty_month1_emplvl_chg':int,  'oty_month1_emplvl_pct_chg':float,  'oty_month2_emplv_chg':int,  'oty_month2_emplvl_pct_chg':float,  'oty_month3_emplvl_chg':int,  'oty_month3_emplvl_pct_chg':float,  'oty_total_qtrly_wages_chg':int,  'oty_total_qtrly_wages_pct_chg':float,  'oty_taxable_qtrly_wages_chg':int,  'oty_taxable_qtrly_wages_pct_chg':float,  'oty_qrtly_contributions_chg':int,  'oty_qrtly_contributions_pct_chg':float,  'oty_avg_wkly_wage_chg':int,  'oty_avg_wkly_wage_pct_chg':float} 

#unused columns from QCEW
drop_columns = ['own_code',  'size_code',  'disclosure_code',  'own_title',  'size_title',  'lq_disclosure_code', 'oty_disclosure_code',  'oty_month1_emplvl_chg',  'oty_month2_emplvl_chg',  'oty_month3_emplvl_chg',  'oty_total_qtrly_wages_chg',  'oty_taxable_qtrly_wages_chg',  'oty_qtrly_contributions_chg',  'oty_avg_wkly_wage_chg',  'lq_qtrly_estabs_count',  'lq_month1_emplvl',  'lq_month2_emplvl',  'lq_month3_emplvl',  'lq_total_qtrly_wages',  'lq_taxable_qtrly_wages',  'lq_qtrly_contributions',  'oty_qtrly_estabs_count_chg',  'oty_qtrly_estabs_count_pct_chg',  'oty_month1_emplvl_pct',  'oty_month2_emplvl_pct',  'oty_month3_emplvl_pct',  'oty_total_qtrly_wages_pct',  'oty_taxable_qtrly_wages_chg',  'oty_qtrly_contributions_pct',  'oty_avg_wkly_wage_pct',  'oty_taxable_qtrly_wages_chg.1',  'lq_avg_wkly_wage',  'taxable_qtrly_wages',  'qtrly_contributions']


def filepath(variable = 'month3_emplvl', dimension = 'area', charttype = 'basic', recession = 2001, filetype = 'json'):
    '''
    creates the filepath to load/save dataframes

        Parameters: 
            initial (bool): indicates if the path created will point to downloaded raw data from the QCEW. Default False.
            year (int): indicates which year of daate will be loaded in initial dataset construction. Default None. Ignored if Initial = False
            variable (str): indicates if the loaded/saved file will contain employment, wage, or firm data. Must be one of ['month3_emplvl' (default), 'avg_wkly_wage', 'qtrly_estabs_count']. Ignored if intitial = True.
            dimension (str): indicates if the loaded/saved file will construct area or industry timelines. Must be one of ['area', 'timeline'].
            charttype (str): indicates what type of timeline will be loaded/saved. Differentiation required for differing chart types in charting.py. Must be one of ['basic', 'target', 'proprtional']. Ignored if initial = True.
            recession (str): indicates the timeframe in question. Must be one of [2001, 2008, 'full']. ignored if initial = True.
            filetype (str): determines what type of file will be saved/loaded. Must be one of ['json', 'csv']. Use 'csv' for loading raw QCEW files.

        Returns:
            df (pandas dataframe): dataframe with column added
    '''
    filename = dim_abbr[dimension] + "_" + var_abbr[variable] + "_" + str(recession) + "." + filetype 
    filepath = "..data/timelines/" + charttype + "/" + dimension + "/" + var_abbr[variable] + '/' +  filename 
    return filepath
    

def add_qtrid(df):
    '''
    Adds a column for the year and quarter. Needed for indexing.

        Parameters: 
            df (pandas dataframe)

        Returns:
            df (pandas dataframe): dataframe with column added
    '''
    df['qtrid'] = df['year'] + (df['qtr']/4)
    return df

def import_all(years, dimension = 'area'):
    '''
    Combines years of data into a single dataframe, adds qtrid

        Parameters: 
            years (list)
            dimension (str): dimension of data to import. Must be 'area' or 'industry'. Default = 'area'

        Returns: 
            df (dataframe)
    '''
    df = import_one(years[0], dimension)
    for year in years[1:]:
        df = df.append(import_one(year, dimension))
    #replaces irregular industry codes and converts to integer
    if dimension == 'industry':
        df['industry_code'] = df['industry_code'].str.replace('31-33','31')
        df['industry_code'] = df['industry_code'].str.replace('44-45','44')
        df['industry_code'] = df['industry_code'].str.replace('48-49','48').astype('int32')
    #adds qtrid column
    df = add_qtrid(df)
    return df

# %%
def import_one(year, dimension = 'area'):
    '''
    Constructs a dataframe from a single year's worth of data.
    
        Parameters: 
            year (str): year of data to be imported
            dimension (str): dimension of data to import. Must be 'area' or 'industry'. Default = 'area'
        
        Returns:
            df (pandas dataframe)
    '''
    filepath = '../data/' + dimension + '_files/' + str(year) + '.csv'
    #all relevant CSVs should be named with only the year
    df = pd.read_csv(filepath, dtype = schema_dict)
    #removes redundant entries in industry files
    if dimension == 'industry':
        df = df[df.own_code != 8]
        df = df[df.own_code != 9]
    for column in drop_columns:
        if column in df.columns:
            df = df.drop([column], axis = 1)
    #removes industry columns from area data
    if dimension == 'area':
        df = df.drop(columns = ['industry_code', 'industry_title'])
    #removes area columns from industry data
    elif dimension == 'industry':
        df = df.drop(columns = ['area_fips', 'area_title'])
    return df

# %%
variable = 'month3_emplvl'
dimension = 'industry'
recession = 2001
save = False
loadjson = False

# %%
df = import_all(recessions_int[2001], 'industry')
df['industry_code'].value_counts()
# Out:
# 10        224
# 5613      128
# 487       128
# 54        128
# 541330    128
#          ...
# 519130     12
# 517919     12
# 517210     12
# 51913      12
# 561312      8
# Name: industry_code, Length: 2385, dtype: int64

# %%
    if dimension == 'area':
        df = df[~df['area_fips'].str.contains("999")]
        index = ['area_fips', 'area_title']
    elif dimension == 'industry':
        index = ['industry_code', 'industry_title']

# %%
    df = import_all(recessions_int[recession], dimension)

# %%
df = df.pivot_table(columns = 'qtrid', values = variable, index = index, aggfunc = np.sum)
df
# Out:
# qtrid                                                            2000.25  \
# industry_code industry_title
# 10            Total, all industries                          402487852.0
# 11            Agriculture, forestry, fishing and hunting       1075812.0
# 21            Mining, quarrying, and oil and gas extraction     501050.0
# 22            Utilities                                         845966.0
# 23            Construction                                     6529756.0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors        83522.0
# 927110        Space research and technology                      17285.0
# 928110        National security                                 524911.0
# 928120        International affairs                              43847.0
# 999999        Unclassified                                           NaN
#
# qtrid                                                            2000.50  \
# industry_code industry_title
# 10            Total, all industries                          412644261.0
# 11            Agriculture, forestry, fishing and hunting       1352286.0
# 21            Mining, quarrying, and oil and gas extraction     514959.0
# 22            Utilities                                         857873.0
# 23            Construction                                     7111232.0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors        85364.0
# 927110        Space research and technology                      18154.0
# 928110        National security                                 528112.0
# 928120        International affairs                              44988.0
# 999999        Unclassified                                           NaN
#
# qtrid                                                            2000.75  \
# industry_code industry_title
# 10            Total, all industries                          410514408.0
# 11            Agriculture, forestry, fishing and hunting       1337463.0
# 21            Mining, quarrying, and oil and gas extraction     521158.0
# 22            Utilities                                         843721.0
# 23            Construction                                     7127272.0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors        85384.0
# 927110        Space research and technology                      17500.0
# 928110        National security                                 521462.0
# 928120        International affairs                              45332.0
# 999999        Unclassified                                           NaN
#
# qtrid                                                            2001.00  \
# industry_code industry_title
# 10            Total, all industries                          413488734.0
# 11            Agriculture, forestry, fishing and hunting       1090392.0
# 21            Mining, quarrying, and oil and gas extraction     520320.0
# 22            Utilities                                         844972.0
# 23            Construction                                     6847425.0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors        85451.0
# 927110        Space research and technology                      17508.0
# 928110        National security                                 520320.0
# 928120        International affairs                              44923.0
# 999999        Unclassified                                           NaN
#
# qtrid                                                            2001.25  \
# industry_code industry_title
# 10            Total, all industries                          406660923.0
# 11            Agriculture, forestry, fishing and hunting       1049212.0
# 21            Mining, quarrying, and oil and gas extraction     523621.0
# 22            Utilities                                         837786.0
# 23            Construction                                     6676321.0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors        86255.0
# 927110        Space research and technology                      17792.0
# 928110        National security                                 516830.0
# 928120        International affairs                              45220.0
# 999999        Unclassified                                      312592.0
#
# qtrid                                                            2001.50  \
# industry_code industry_title
# 10            Total, all industries                          412554119.0
# 11            Agriculture, forestry, fishing and hunting       1315058.0
# 21            Mining, quarrying, and oil and gas extraction     548175.0
# 22            Utilities                                         851427.0
# 23            Construction                                     7237914.0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors        87439.0
# 927110        Space research and technology                      17560.0
# 928110        National security                                 521809.0
# 928120        International affairs                              46492.0
# 999999        Unclassified                                      299885.0
#
# qtrid                                                            2001.75  \
# industry_code industry_title
# 10            Total, all industries                          407651445.0
# 11            Agriculture, forestry, fishing and hunting       1291827.0
# 21            Mining, quarrying, and oil and gas extraction     547480.0
# 22            Utilities                                         841093.0
# 23            Construction                                     7200035.0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors        87709.0
# 927110        Space research and technology                      17657.0
# 928110        National security                                 520243.0
# 928120        International affairs                              46636.0
# 999999        Unclassified                                      251654.0
#
# qtrid                                                            2002.00  \
# industry_code industry_title
# 10            Total, all industries                          406860089.0
# 11            Agriculture, forestry, fishing and hunting       1063966.0
# 21            Mining, quarrying, and oil and gas extraction     531137.0
# 22            Utilities                                         843745.0
# 23            Construction                                     6868261.0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors        86369.0
# 927110        Space research and technology                      17528.0
# 928110        National security                                 515632.0
# 928120        International affairs                              47374.0
# 999999        Unclassified                                      209993.0
#
# qtrid                                                            2002.25  \
# industry_code industry_title
# 10            Total, all industries                          400229102.0
# 11            Agriculture, forestry, fishing and hunting       1037388.0
# 21            Mining, quarrying, and oil and gas extraction     505017.0
# 22            Utilities                                         838292.0
# 23            Construction                                     6578842.0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors        86574.0
# 927110        Space research and technology                      17336.0
# 928110        National security                                 509815.0
# 928120        International affairs                              50275.0
# 999999        Unclassified                                      227896.0
#
# qtrid                                                            2002.50  ...  \
# industry_code industry_title                                              ...
# 10            Total, all industries                          407450305.0  ...
# 11            Agriculture, forestry, fishing and hunting       1288052.0  ...
# 21            Mining, quarrying, and oil and gas extraction     513124.0  ...
# 22            Utilities                                         846349.0  ...
# 23            Construction                                     7087261.0  ...
# ...                                                                  ...  ...
# 926150        Licensing and regulating commercial sectors        87431.0  ...
# 927110        Space research and technology                      17516.0  ...
# 928110        National security                                 515117.0  ...
# 928120        International affairs                              50581.0  ...
# 999999        Unclassified                                      227740.0  ...
#
# qtrid                                                            2005.75  \
# industry_code industry_title
# 10            Total, all industries                          417266345.0
# 11            Agriculture, forestry, fishing and hunting       1267224.0
# 21            Mining, quarrying, and oil and gas extraction     576466.0
# 22            Utilities                                         806842.0
# 23            Construction                                     7797614.0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors
0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors        93506.0
# 927110        Space research and technology                      18383.0
# 928110        National security                                 494847.0
# 928120        International affairs                              27969.0
# 999999        Unclassified                                      228823.0
#
# qtrid                                                            2007.75  \
# industry_code industry_title
# 10            Total, all industries                          427422632.0
# 11            Agriculture, forestry, fishing and hunting       1268424.0
# 21            Mining, quarrying, and oil and gas extraction     671695.0
# 22            Utilities                                         808172.0
# 23            Construction                                     7964881.0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors        93178.0
# 927110        Space research and technology                      18562.0
# 928110        National security                                 486465.0
# 928120        International affairs                              28352.0
# 999999        Unclassified                                      219578.0
#
# qtrid                                                            2008.00
# industry_code industry_title
# 10            Total, all industries                          430316935.0
# 11            Agriculture, forestry, fishing and hunting       1097346.0
# 21            Mining, quarrying, and oil and gas extraction     674796.0
# 22            Utilities                                         810581.0
# 23            Construction                                     7577859.0
# ...                                                                  ...
# 926150        Licensing and regulating commercial sectors        93580.0
# 927110        Space research and technology                      18518.0
# 928110        National security                                 490141.0
# 928120        International affairs                              28559.0
# 999999        Unclassified                                      239416.0
#
# [2385 rows x 32 columns]

# %%
df = df.reset_index()
df = df.fillna(0)
df
# Out:
# qtrid  industry_code                                 industry_title  \
# 0                 10                          Total, all industries
# 1                 11     Agriculture, forestry, fishing and hunting
# 2                 21  Mining, quarrying, and oil and gas extraction
# 3                 22                                      Utilities
# 4                 23                                   Construction
# ...              ...                                            ...
# 2380          926150    Licensing and regulating commercial sectors
# 2381          927110                  Space research and technology
# 2382          928110                              National security
# 2383          928120                          International affairs
# 2384          999999                                   Unclassified
#
# qtrid      2000.25       2000.5      2000.75       2001.0      2001.25  \
# 0      402487852.0  412644261.0  410514408.0  413488734.0  406660923.0
# 1        1075812.0    1352286.0    1337463.0    1090392.0    1049212.0
# 2         501050.0     514959.0     521158.0     520320.0     523621.0
# 3         845966.0     857873.0     843721.0     844972.0     837786.0
# 4        6529756.0    7111232.0    7127272.0    6847425.0    6676321.0
# ...            ...          ...          ...          ...          ...
# 2380       83522.0      85364.0      85384.0      85451.0      86255.0
# 2381       17285.0      18154.0      17500.0      17508.0      17792.0
# 2382      524911.0     528112.0     521462.0     520320.0     516830.0
# 2383       43847.0      44988.0      45332.0      44923.0      45220.0
# 2384           0.0          0.0          0.0          0.0     312592.0
#
# qtrid       2001.5      2001.75       2002.0  ...      2005.75       2006.0  \
# 0      412554119.0  407651445.0  406860089.0  ...  417266345.0  420148526.0
# 1        1315058.0    1291827.0    1063966.0  ...    1267224.0    1077805.0
# 2         548175.0     547480.0     531137.0  ...     576466.0     582019.0
# 3         851427.0     841093.0     843745.0  ...     806842.0     805409.0
# 4        7237914.0    7200035.0    6868261.0  ...    7797614.0    7598097.0
# ...            ...          ...          ...  ...          ...          ...
# 2380       87439.0      87709.0      86369.0  ...      90566.0      90393.0
# 2381       17560.0      17657.0      17528.0  ...      18881.0      18652.0
# 2382      521809.0     520243.0     515632.0  ...     487574.0     489947.0
# 2383       46492.0      46636.0      47374.0  ...      27413.0      27151.0
# 2384      299885.0     251654.0     209993.0  ...     293730.0     282851.0
#
# qtrid      2006.25       2006.5      2006.75       2007.0      2007.25  \
# 0      416358183.0  424753488.0  423598265.0  426746034.0  421871312.0
# 1        1046168.0    1296048.0    1270056.0    1088800.0    1051329.0
# 2         591513.0     623670.0     637134.0     639394.0     640446.0
# 3         799474.0     810353.0     805169.0     804724.0     803468.0
# 4        7488845.0    8077867.0    8046796.0    7728629.0    7511641.0
# ...            ...          ...          ...          ...          ...
# 2380       90479.0      91375.0      91123.0      91603.0      91963.0
# 2381       18435.0      18391.0      18585.0      18461.0      18355.0
# 2382      490007.0     494863.0     487739.0     493968.0     490295.0
# 2383       27596.0      27158.0      28067.0      27789.0      27762.0
# 2384      259895.0     248339.0     269987.0     269621.0     237359.0
#
# qtrid       2007.5      2007.75       2008.0
# 0      429850192.0  427422632.0  430316935.0
# 1        1301066.0    1268424.0    1097346.0
# 2         668268.0     671695.0     674796.0
# 3         817883.0     808172.0     810581.0
# 4        8042658.0    7964881.0    7577859.0
# ...            ...          ...          ...
# 2380       93506.0      93178.0      93580.0
# 2381       18383.0      18562.0      18518.0
# 2382      494847.0     486465.0     490141.0
# 2383       27969.0      28352.0      28559.0
# 2384      228823.0     219578.0     239416.0
#
# [2385 rows x 34 columns]

# %%
    if dimension == 'area':
        df = df[~df['area_fips'].str.contains("999")]
        index = ['area_fips', 'area_title']
    elif dimension == 'industry':
        index = ['industry_code', 'industry_title']

# %%
df2 = df.drop(columns = index)
df2 = df2.reset_index()

#drops the index so that all calculations are free of any type mismatches
df2 = df2.drop(columns = 'index')
df2 = df2.fillna(0)

#specifies the lowest numbers during the recession. Disregards quarters before the recession event. 
df2['nadir'] = df2.iloc[:,6:].min(axis=1)

#specifies which quarter the nadir occured.
df2['nadir_qtr'] = (df2.iloc[:,6:].idxmin(axis=1).apply(lambda x: df.columns.get_loc(x)))-1

#creates a column to store indices for lookup.
df2['new'] = [df2.iloc[i].values for i in df.index]

#specifies the highest numbers *before* the nadir.
df2['pre_peak'] = df2.apply(lambda x: max(x['new'][0:x['nadir_qtr']]), axis=1)

#specifies the highest numbers *after* the nadir
df2['post_peak'] = df2.apply(lambda x: max(x['new'][x['nadir_qtr']:]), axis=1) 

#specifies which quarter the pre-peak occurred.
df2['pre_peak_qtr'] = pd.Series([s[i] for i, s in zip(df2.index, df2['pre_peak'].apply(
    lambda x: [i for i in (df2.iloc[:,0:-6] == x)
            .idxmax(axis=1)]))]).apply(lambda x: df2.columns.get_loc(x)) + 1

#specifies which quarter the post-peak occurred.
df2['post_peak_qtr'] = pd.Series([s[i] for i, s in zip(df2.index, df2['post_peak'].apply(
    lambda x: [i for i in (df2.iloc[:,0:-6] == x)
            .idxmax(axis=1)]))]).apply(lambda x: df2.columns.get_loc(x)) + 1

#PRIMARY TARGET: did the area/industry achieve it's pre-recession peak?
df2['recovery'] = (df2['post_peak'] >= df2['pre_peak']) *1

#create another dataframe to calculate the # of quarters to recover- only contains recovered datapoints
df3 = df2[df2['recovery'] == 1]

#creates a column to derive the recovery quarter- list of boolean values
df3['recovery_list'] = df3.apply(lambda x: (x['new'][x['nadir_qtr']:] >= x['pre_peak']), axis=1)

#creates a column for the number or quarters until the results pass the pre-peak high, since the nadir
df3['recovery_qtr'] = df3['recovery_list'].apply(lambda x: list(x).index(True)) + 1

#drops all redunant fields from the third dataframe
if loadjson:
    df3 = df3.drop(columns = dropcols_str[recession])
else:
    df3 = df3.drop(columns = dropcols_flt[recession])
# if recession == 2001:
#     dropcols = timeline2001_dropcols
# elif recession == 2008:
#     dropcols = timeline2008_dropcols
# elif recession == 'full':
#     dropcols = timelinefull_dropcols
# df3 = df3.drop(columns = dropcols)

#creates a new dataframe to store derived fields
df_new = df2[['nadir', 'nadir_qtr', 'pre_peak', 'pre_peak_qtr', 'post_peak', 'post_peak_qtr', 'recovery']]

#adds the recovery quarter column from the third dataframe
df_new = df_new.join(df3, how = 'left', rsuffix = '_recov')

#puts the computed points in a dataframe, joins with timeline
df = df.join(df_new, how = 'outer', rsuffix = '_derive')

#How many quarters did the jobs numbers decline?
df['decline'] = (df['nadir_qtr'] - df['pre_peak_qtr'])

#Different in before/after jobs numbers
df['delta'] = df['post_peak'] - df['pre_peak']
df
# Out:
# qtrid  industry_code                                 industry_title  \
# 0                 10                          Total, all industries
# 1                 11     Agriculture, forestry, fishing and hunting
# 2                 21  Mining, quarrying, and oil and gas extraction
# 3                 22                                      Utilities
# 4                 23                                   Construction
# ...              ...                                            ...
# 2380          926150    Licensing and regulating commercial sectors
# 2381          927110                  Space research and technology
# 2382          928110                              National security
# 2383          928120                          International affairs
# 2384          999999                                   Unclassified
#
# qtrid      2000.25       2000.5      2000.75       2001.0      2001.25  \
# 0      402487852.0  412644261.0  410514408.0  413488734.0  406660923.0
# 1        1075812.0    1352286.0    1337463.0    1090392.0    1049212.0
# 2         501050.0     514959.0     521158.0     520320.0     523621.0
# 3         845966.0     857873.0     843721.0     844972.0     837786.0
# 4        6529756.0    7111232.0    7127272.0    6847425.0    6676321.0
# ...            ...          ...          ...          ...          ...
# 2380       83522.0      85364.0      85384.0      85451.0      86255.0
# 2381       17285.0      18154.0      17500.0      17508.0      17792.0
# 2382      524911.0     528112.0     521462.0     520320.0     516830.0
# 2383       43847.0      44988.0      45332.0      44923.0      45220.0
# 2384           0.0          0.0          0.0          0.0     312592.0
#
# qtrid       2001.5      2001.75       2002.0  ...        nadir  nadir_qtr  \
# 0      412554119.0  407651445.0  406860089.0  ...  398565014.0         13
# 1        1315058.0    1291827.0    1063966.0  ...    1037388.0          9
# 2         548175.0     547480.0     531137.0  ...     489785.0         13
# 3         851427.0     841093.0     843745.0  ...     799474.0         25
# 4        7237914.0    7200035.0    6868261.0  ...    6480697.0         13
# ...            ...          ...          ...  ...          ...        ...
# 2380       87439.0      87709.0      86369.0  ...      86369.0          8
# 2381       17560.0      17657.0      17528.0  ...      17287.0         17
# 2382      521809.0     520243.0     515632.0  ...     482175.0         21
# 2383       46492.0      46636.0      47374.0  ...      26464.0         19
# 2384      299885.0     251654.0     209993.0  ...     204729.0         13
#
# qtrid     pre_peak  pre_peak_qtr    post_peak  post_peak_qtr  recovery  \
# 0      413488734.0             4  430316935.0             32         1
# 1        1352286.0             2    1303145.0             14         0
# 2         548175.0             6     674796.0             32         1
# 3         857873.0             2     817883.0             30         0
# 4        7237914.0             6    8077867.0             26         1
# ...            ...           ...          ...            ...       ...
# 2380       87709.0             7      93580.0             32         1
# 2381       18154.0             2      19159.0             20         1
# 2382      528112.0             2     494863.0             26         0
# 2383       52431.0            12      28559.0             32         0
# 2384      312592.0             5     293730.0             23         0
#
# qtrid  recovery_qtr  decline       delta
# 0               9.0        9  16828201.0
# 1               NaN        7    -49141.0
# 2               9.0        7    126621.0
# 3               NaN       23    -39990.0
# 4               5.0        7    839953.0
# ...             ...      ...         ...
# 2380            5.0        1      5871.0
# 2381            3.0       15      1005.0
# 2382            NaN       19    -33249.0
# 2383            NaN        7    -23872.0
# 2384            NaN        8    -18862.0
#
# [2385 rows x 44 columns]

# %%
charttypes = ['basic', 'target', 'proportional']
dimensions = ['area', 'industry']
recessions = [2001, 2008, 'full']
variables = ['month3_emplvl', 'avg_wkly_wage', 'qtrly_estabs_count']

# %%
for recession in recessions:
    for charttype in charttypes:
        for dimension in dimensions: 
            for variable in variables: 
                loadpath = filepath(variable, dimension, charttype, recession)
                df=pd.read_json(loadpath)
                if (recession == 'full') and (charttype ==  'target'):
                    print(f'skipping {charttype} - {dimension} - {variable} - {recession}')
                    continue
                print(f'analyzing {charttype} - {dimension} - {variable} - {recession}')
                print(df.info())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-f3e2c8a1d15d> in <module>
#       4             for variable in variables:
#       5                 loadpath = filepath(variable, dimension, charttype, recession)
# ----> 6                 df=pd.read_json(loadpath)
#       7                 if (recession == 'full') and (charttype ==  'target'):
#       8                     print(f'skipping {charttype} - {dimension} - {variable} - {recession}')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     616         return json_reader
#     617
# --> 618     result = json_reader.read()
#     619     if should_close:
#     620         filepath_or_buffer.close()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in read(self)
#     753                 obj = self._get_object_parser(self._combine_lines(data))
#     754         else:
# --> 755             obj = self._get_object_parser(self.data)
#     756         self.close()
#     757         return obj
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     775         obj = None
#     776         if typ == "frame":
# --> 777             obj = FrameParser(json, **kwargs).parse()
#     778
#     779         if typ == "series" or obj is None:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in parse(self)
#     884
#     885         else:
# --> 886             self._parse_no_numpy()
#     887
#     888         if self.obj is None:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1117         if orient == "columns":
#    1118             self.obj = DataFrame(
# -> 1119                 loads(json, precise_float=self.precise_float), dtype=None
#    1120             )
#    1121         elif orient == "split":
#
# ValueError: Expected object or value

# %% [markdown]
#
#
#     #set indicies, drop unhelpful rows
#
#
#     #pivots the table to arrange quarters in columns, drops extraneous variables.
#
#
#     #fill nans
#     df = df.fillna(0)
#
#     #export the data
#     if save:
#         savepath = filepath(initial = False, variable = variable, dimension = dimension, recession = recession, filetype = 'json')
#
#             # "data/timelines/basic" + dim_abbr[dimension] + "_" + var_abbr[variable] + "_" + str(recession) + ".json"
#         df.to_json(savepath)
#     return df
