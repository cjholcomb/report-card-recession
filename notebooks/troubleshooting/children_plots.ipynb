# %%
import os
os.chdir('/home/cj/Documents/dsi/capstones/report-card-recession/src')
from charting import *

# %%
os.chdir('/home/cj/Documents/dsi/capstones/report-card-recession')
test = Vector(1024, recession = 2001, variable = 'wage')
vars(test)
# Out:
# {'key': 1024,
#  'recession': <classes.Recession at 0x7ff762503610>,
#  'dimension': 'industry',
#  'variable': 'wage',
#  'index_col': 'industry_code',
#  'index_title': 'industry_title',
#  'row': <classes.Industry at 0x7ff77a6be160>,
#  'df':                                               industry_title  2000.25  2000.5  \
#  industry_code
#  10                                     Total, all industries     4938    4810
#  11                Agriculture, forestry, fishing and hunting     2116    2233
#  21             Mining, quarrying, and oil and gas extraction     1158    1065
#  22                                                 Utilities     4639    4226
#  23                                              Construction     2665    2522
#  ...                                                      ...      ...     ...
#  926150           Licensing and regulating commercial sectors     2570    2705
#  927110                         Space research and technology     1202    1276
# ...

# %%
loadpath = filepath(variable = 'wage', dimension = 'industry', charttype= 'target', recession = 2001, filetype = 'json')
df = pd.read_json(loadpath)
df
# Out:
#       industry_code                                 industry_title  2000.25  \
# 0                10                          Total, all industries     4938
# 1                11     Agriculture, forestry, fishing and hunting     2116
# 2                21  Mining, quarrying, and oil and gas extraction     1158
# 3                22                                      Utilities     4639
# 4                23                                   Construction     2665
# ...             ...                                            ...      ...
# 2380         926150    Licensing and regulating commercial sectors     2570
# 2381         927110                  Space research and technology     1202
# 2382         928110                              National security     1546
# 2383         928120                          International affairs     2039
# 2384         999999                                   Unclassified        0
#
# ...
