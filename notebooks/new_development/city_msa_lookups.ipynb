# %%
import os
os.chdir('/home/cj/Documents/dsi/capstones/report-card-recession')
import pandas as pd 
from src.areas import *

# %%
df = pd.read_csv('data/2020_census_MSA_lookup.csv', dtype = str)
df['area_fips'] = df['FIPS State Code'] + df['FIPS County Code']
df.sort_values(by = 'area_fips')['area_fips']
# Out:
# 71      01001
# 73      01003
# 81      01005
# 128     01007
# 136     01009
#         ...
# 1759    72143
# 1760    72145
# 1769    72149
# 1897    72151
# 1903    72153
# Name: area_fips, Length: 1916, dtype: object

# %%
for fips in area_titles.keys():
    if fips not in df.sort_values(by = 'area_fips')['area_fips']:
        mismatch = True
        print(fips)
# Out:
# US000
# 01000
# 01001
# 01003
# 01005
# 01007
# 01009
# 01011
# 01013
# 01015
# 01017
# 01019
# 01021
# 01023
# 01025
# 01027
# 01029
# 01031
# 01033
# 01035
# 01037
# 01039
# 01041
# 01043
# 01045
# 01047
# 01049
# 01051
# 01053
# 01055
# 01057
# 01059
# 01061
# 01063
# 01065
# 01067
# 01069
# 01071
# 01073
# 01075
# 01077
# 01079
# 01081
# 01083
# 01085
# 01087
# 01089
# 01091
# 01093
# 01095
# 01097
# 01099
# 01101
# 01103
# 01105
# 01107
# 01109
# 01111
# 01113
# 01115
# 01117
# 01119
# 01121
# 01123
# 01125
# 01127
# 01129
# 01131
# 01133
# 01996
# 01997
# 01998
# 01999
# 02000
# 02010
# 02013
# 02016
# 02020
# 02030
# 02040
# 02050
# 02060
# 02068
# 02070
# 02080
# 02090
# 02100
# 02105
# 02110
# 02120
# 02122
# 02130
# 02140
# 02150
# 02160
# 02164
# 02170
# 02180
# 02185
# 02188
# 02190
# 02195
# 02198
# 02200
# 02201
# 02210
# 02220
# 02230
# 02231
# 02232
# 02240
# 02250
# 02260
# 02261
# 02270
# 02275
# 02280
# 02282
# 02290
# 02996
# 02997
# 02998
# 02999
# 04000
# 04001
# ...

# %%
for fips in df.sort_values(by = 'area_fips')['area_fips']:
    print(fips)
# Out:
# 01001
# 01003
# 01005
# 01007
# 01009
# 01015
# 01017
# 01021
# 01031
# 01033
# 01037
# 01043
# 01045
# 01047
# 01049
# 01051
# 01053
# 01055
# 01061
# 01063
# 01065
# 01067
# 01069
# 01071
# 01073
# 01077
# 01079
# 01081
# 01083
# 01085
# 01089
# 01095
# 01097
# 01101
# 01103
# 01107
# 01109
# 01113
# 01115
# 01117
# 01121
# 01123
# 01125
# 01127
# 01129
# 02020
# 02090
# 02110
# 02130
# 02170
# 04003
# 04005
# 04007
# 04009
# 04013
# 04015
# 04017
# 04019
# 04021
# 04023
# 04025
# 04027
# 05005
# 05007
# 05009
# 05013
# 05019
# 05025
# 05027
# 05031
# 05033
# 05035
# 05045
# 05047
# 05051
# 05053
# 05055
# 05057
# 05059
# 05063
# 05069
# 05079
# 05081
# 05085
# 05087
# 05091
# 05093
# 05099
# 05101
# 05103
# 05105
# 05107
# 05111
# 05115
# 05119
# 05123
# 05125
# 05131
# 05135
# 05139
# 05143
# 05145
# 05149
# 06001
# 06007
# 06013
# 06015
# 06017
# 06019
# 06023
# 06025
# 06029
# 06031
# 06033
# 06035
# 06037
# 06039
# 06041
# 06045
# 06047
# 06053
# 06055
# 06057
# 06059
# 06061
# ...

# %%
area_titles.keys()
# Out:
# dict_keys(['US000', '01000', '01001', '01003', '01005', '01007', '01009', '01011', '01013', '01015', '01017', '01019', '01021', '01023', '01025', '01027', '01029', '01031', '01033', '01035', '01037', '01039', '01041', '01043', '01045', '01047', '01049', '01051', '01053', '01055', '01057', '01059', '01061', '01063', '01065', '01067', '01069', '01071', '01073', '01075', '01077', '01079', '01081', '01083', '01085', '01087', '01089', '01091', '01093', '01095', '01097', '01099', '01101', '01103', '01105', '01107', '01109', '01111', '01113', '01115', '01117', '01119', '01121', '01123', '01125', '01127', '01129', '01131', '01133', '01996', '01997', '01998', '01999', '02000', '02010', '02013', '02016', '02020', '02030', '02040', '02050', '02060', '02068', '02070', '02080', '02090', '02100', '02105', '02110', '02120', '02122', '02130', '02140', '02150', '02160', '02164', '02170', '02180', '02185', '02188', '02190', '02195', '02198', '02200', '02201', '02210', '02220', '02230', '02231', '02232
# ...

# %%
print(len(df['area_fips']))
print(len(area_titles))
# Out:
# 1916
# 4593

# %%
for column in df.columns:
    print(column)
    print(df[column].value_counts())
# Out:
# CBSA Code
# 41980    40
# 12060    29
# 47900    25
# 35620    23
# 47260    19
#          ..
# 27100     1
# 40820     1
# 42500     1
# 32780     1
# 43700     1
# Name: CBSA Code, Length: 939, dtype: int64
# Metropolitan Division Code
# 47894    23
# 35614    11
# 19124     7
# 35084     6
# 47664     5
# 16984     5
# 35154     4
# 23844     4
# 23104     4
# 33874     3
# 14454     3
# 20994     3
# 48864     3
# 15804     3
# 40484     2
# 23224     2
# 15764     2
# 35004     2
# 29404     2
# 37964     2
# 42644     2
# 41884     2
# 36084     2
# 45104     1
# 42034     1
# 22744     1
# 31084     1
# 11244     1
# 19804     1
# 33124     1
# 48424     1
# Name: Metropolitan Division Code, dtype: int64
# CSA Code
# 490    48
# 122    42
# 548    41
# 408    31
# 312    22
#        ..
# 536     2
# 393     2
# 558     2
# 362     2
# 217     2
# Name: CSA Code, Length: 175, dtype: int64
# CBSA Title
# San Juan-Bayamón-Caguas PR                     40
# ...
