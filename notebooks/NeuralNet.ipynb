# %%
from src.dictionaries import *
import pandas as pd
import numpy as np
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.metrics import AUC
from keras.metrics import categorical_crossentropy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import kerastuner as kt

# %%
df = pd.read_json('data/training_dataset.json')
df.shape

# %%
X = df.loc[:,features].values
y_recovery = df.loc[:,['recovery']].values * 1
y_delta = df.loc[:,['delta']].values
X_train, X_test, y_train, y_test = train_test_split(X, y_recovery, test_size=.2, stratify = y_recovery)
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
type(X_train)

# %%
y_train.shape
# Out:
# (7047, 1)

# %%
model = Sequential([
    Dense(2388, input_shape = (2388,), activation = 'sigmoid'),
    Dense(50, activation = 'sigmoid'),
    Dense(100, activation = 'sigmoid'),
    Dense(32, activation = 'sigmoid'),
    Dense(1, activation = 'sigmoid')])

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_32 (Dense)             (None, 2388)              5704932
# _________________________________________________________________
# dense_33 (Dense)             (None, 50)                119450
# _________________________________________________________________
# dense_34 (Dense)             (None, 100)               5100
# _________________________________________________________________
# dense_35 (Dense)             (None, 32)                3232
# _________________________________________________________________
# dense_36 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 5,832,747
# Trainable params: 5,832,747
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(lr = 0.1), loss ='binary_crossentropy', metrics=['AUC'])

# %%
model.fit(X_train, y_train, epochs = 100, shuffle = True,verbose = 2)
# Out:
# Epoch 1/100
# 221/221 - 10s - loss: 0.6930 - auc: 0.4981
# Epoch 2/100
# 221/221 - 11s - loss: 0.6932 - auc: 0.5039
# Epoch 3/100
# 221/221 - 11s - loss: 0.6933 - auc: 0.5019
# Epoch 4/100
# 221/221 - 11s - loss: 0.6970 - auc: 0.4835
# Epoch 5/100
# 221/221 - 12s - loss: 0.6920 - auc: 0.5048
# Epoch 6/100
# 221/221 - 13s - loss: 0.6944 - auc: 0.4808
# Epoch 7/100
# 221/221 - 12s - loss: 0.6940 - auc: 0.4976
# Epoch 8/100
# 221/221 - 11s - loss: 0.6928 - auc: 0.4973
# Epoch 9/100
# 221/221 - 11s - loss: 0.6927 - auc: 0.4965
# Epoch 10/100
# 221/221 - 11s - loss: 0.6933 - auc: 0.5006
# Epoch 11/100
# 221/221 - 12s - loss: 0.6948 - auc: 0.5004
# Epoch 12/100
# 221/221 - 11s - loss: 0.6950 - auc: 0.5040
# Epoch 13/100
# 221/221 - 11s - loss: 0.6962 - auc: 0.5049
# Epoch 14/100
# 221/221 - 12s - loss: 0.6934 - auc: 0.5035
# Epoch 15/100
# 221/221 - 11s - loss: 0.6937 - auc: 0.5061
# Epoch 16/100
# 221/221 - 11s - loss: 0.6933 - auc: 0.4981
# Epoch 17/100
# 221/221 - 13s - loss: 0.6956 - auc: 0.4942
# Epoch 18/100
# 221/221 - 13s - loss: 0.6939 - auc: 0.4931
# Epoch 19/100
# 221/221 - 14s - loss: 0.6924 - auc: 0.4990
# Epoch 20/100
# 221/221 - 14s - loss: 0.6941 - auc: 0.4964
# Epoch 21/100
# 221/221 - 12s - loss: 0.6915 - auc: 0.5074
# Epoch 22/100
# 221/221 - 12s - loss: 0.6941 - auc: 0.4977
# Epoch 23/100
# 221/221 - 12s - loss: 0.6935 - auc: 0.4925
# Epoch 24/100
# 221/221 - 13s - loss: 0.6965 - auc: 0.4827
# Epoch 25/100
# 221/221 - 13s - loss: 0.6928 - auc: 0.5076
# Epoch 26/100
# 221/221 - 12s - loss: 0.6942 - auc: 0.4950
# Epoch 27/100
# 221/221 - 12s - loss: 0.6938 - auc: 0.4880
# Epoch 28/100
# 221/221 - 11s - loss: 0.6917 - auc: 0.5119
# Epoch 29/100
# 221/221 - 11s - loss: 0.6959 - auc: 0.4887
# Epoch 30/100
# 221/221 - 11s - loss: 0.6933 - auc: 0.5012
# Epoch 31/100
# 221/221 - 11s - loss: 0.6924 - auc: 0.4944
# Epoch 32/100
# 221/221 - 12s - loss: 0.6929 - auc: 0.5082
# Epoch 33/100
# 221/221 - 11s - loss: 0.6943 - auc: 0.5101
# Epoch 34/100
# 221/221 - 11s - loss: 0.6926 - auc: 0.4942
# Epoch 35/100
# 221/221 - 12s - loss: 0.6947 - auc: 0.4948
# Epoch 36/100
# 221/221 - 11s - loss: 0.6950 - auc: 0.5036
# Epoch 37/100
# 221/221 - 11s - loss: 0.6962 - auc: 0.4971
# Epoch 38/100
# 221/221 - 11s - loss: 0.6917 - auc: 0.5056
# Epoch 39/100
# 221/221 - 12s - loss: 0.6937 - auc: 0.4945
# Epoch 40/100
# 221/221 - 11s - loss: 0.6927 - auc: 0.5077
# Epoch 41/100
# 221/221 - 11s - loss: 0.6942 - auc: 0.5077
# Epoch 42/100
# 221/221 - 11s - loss: 0.6935 - auc: 0.5064
# Epoch 43/100
# 221/221 - 11s - loss: 0.6932 - auc: 0.5004
# Epoch 44/100
# 221/221 - 11s - loss: 0.6954 - auc: 0.4892
# Epoch 45/100
# 221/221 - 10s - loss: 0.6938 - auc: 0.4981
# Epoch 46/100
# 221/221 - 12s - loss: 0.6949 - auc: 0.4994
# Epoch 47/100
# 221/221 - 13s - loss: 0.6934 - auc: 0.5006
# Epoch 48/100
# 221/221 - 12s - loss: 0.6939 - auc: 0.5035
# Epoch 49/100
# 221/221 - 11s - loss: 0.6947 - auc: 0.4908
# Epoch 50/100
# 221/221 - 10s - loss: 0.6931 - auc: 0.5052
# Epoch 51/100
# 221/221 - 11s - loss: 0.6958 - auc: 0.4889
# Epoch 52/100
# 221/221 - 11s - loss: 0.6936 - auc: 0.5011
# Epoch 53/100
# 221/221 - 12s - loss: 0.6927 - auc: 0.4983
# Epoch 54/100
# 221/221 - 12s - loss: 0.6966 - auc: 0.4795
# Epoch 55/100
# 221/221 - 11s - loss: 0.6933 - auc: 0.4953
# Epoch 56/100
# 221/221 - 11s - loss: 0.6937 - auc: 0.4991
# Epoch 57/100
# 221/221 - 11s - loss: 0.6941 - auc: 0.5162
# Epoch 58/100
# 221/221 - 11s - loss: 0.6952 - auc: 0.4979
# Epoch 59/100
# 221/221 - 11s - loss: 0.6961 - auc: 0.4902
# Epoch 60/100
# 221/221 - 11s - loss: 0.6926 - auc: 0.5027
# Epoch 61/100
# 221/221 - 11s - loss: 0.6933 - auc: 0.4969
# Epoch 62/100
# 221/221 - 11s - loss: 0.6924 - auc: 0.5029
# Epoch 63/100
# 221/221 - 11s - loss: 0.6946 - auc: 0.4928
# Epoch 64/100
# 221/221 - 11s - loss: 0.6935 - auc: 0.4881
# Epoch 65/100
# 221/221 - 11s - loss: 0.6938 - auc: 0.4964
# Epoch 66/100
# 221/221 - 11s - loss: 0.6942 - auc: 0.4947
# Epoch 67/100
# 221/221 - 11s - loss: 0.6932 - auc: 0.5061
# Epoch 68/100
# 221/221 - 11s - loss: 0.6920 - auc: 0.5103
# Epoch 69/100
# 221/221 - 11s - loss: 0.6937 - auc: 0.4860
# Epoch 70/100
# 221/221 - 11s - loss: 0.6926 - auc: 0.5068
# Epoch 71/100
# 221/221 - 12s - loss: 0.6976 - auc: 0.4876
# Epoch 72/100
# 221/221 - 11s - loss: 0.6938 - auc: 0.5000
# Epoch 73/100
# 221/221 - 12s - loss: 0.6926 - auc: 0.5008
# Epoch 74/100
# 221/221 - 11s - loss: 0.6923 - auc: 0.5020
# Epoch 75/100
# 221/221 - 11s - loss: 0.6932 - auc: 0.5069
# Epoch 76/100
# 221/221 - 11s - loss: 0.6930 - auc: 0.5049
# Epoch 77/100
# 221/221 - 10s - loss: 0.6928 - auc: 0.5063
# Epoch 78/100
# 221/221 - 11s - loss: 0.6947 - auc: 0.5012
# Epoch 79/100
# 221/221 - 11s - loss: 0.6944 - auc: 0.5017
# Epoch 80/100
# 221/221 - 10s - loss: 0.6934 - auc: 0.5007
# Epoch 81/100
# 221/221 - 11s - loss: 0.6939 - auc: 0.4980
# Epoch 82/100
# 221/221 - 11s - loss: 0.6926 - auc: 0.5034
# Epoch 83/100
# 221/221 - 10s - loss: 0.6929 - auc: 0.4995
# Epoch 84/100
# 221/221 - 11s - loss: 0.6964 - auc: 0.4997
# Epoch 85/100
# 221/221 - 10s - loss: 0.6942 - auc: 0.4865
# Epoch 86/100
# 221/221 - 11s - loss: 0.6939 - auc: 0.4939
# Epoch 87/100
# 221/221 - 11s - loss: 0.6938 - auc: 0.4989
# Epoch 88/100
# 221/221 - 10s - loss: 0.6956 - auc: 0.5039
# Epoch 89/100
# 221/221 - 11s - loss: 0.6937 - auc: 0.4906
# Epoch 90/100
# 221/221 - 11s - loss: 0.6942 - auc: 0.4944
# Epoch 91/100
# 221/221 - 10s - loss: 0.6930 - auc: 0.4985
# Epoch 92/100
# 221/221 - 12s - loss: 0.6932 - auc: 0.5030
# Epoch 93/100
# 221/221 - 10s - loss: 0.6939 - auc: 0.4948
# Epoch 94/100
# 221/221 - 11s - loss: 0.6939 - auc: 0.5006
# Epoch 95/100
# 221/221 - 11s - loss: 0.6946 - auc: 0.4929
# Epoch 96/100
# 221/221 - 11s - loss: 0.6947 - auc: 0.4961
# Epoch 97/100
# 221/221 - 10s - loss: 0.6928 - auc: 0.4965
# Epoch 98/100
# 221/221 - 11s - loss: 0.6943 - auc: 0.4969
# Epoch 99/100
# 221/221 - 10s - loss: 0.6925 - auc: 0.5042
# Epoch 100/100
# 221/221 - 10s - loss: 0.6944 - auc: 0.4899
